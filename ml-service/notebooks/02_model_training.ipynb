# %%
from pathlib import Path

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

import sys
if str(ROOT) not in sys.path:
    sys.path.append(str(ROOT))

# %%
from training.train_baseline_model import clean_dataset, load_dataset, train_model

dataset = clean_dataset(load_dataset())
dataset.head()

# %%
model, metrics = train_model(dataset)
metrics
